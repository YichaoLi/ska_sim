# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
from matplotlib import pyplot as plt
import healpy as hp


from ska_sim import diffuse
from ska_sim import plot_map as pm

# %%
sim_path = '/home/DATA/ycli/ska_challenge/2023/'
temp_file = '/home/DATA/shaoyue/data_challenge_900/lightcones_brightness_xy600_z900_r20230200.h5'
temp_key  = 'delta_T'
sck_params = {'A': 700.}
output_path = sim_path + 'diffuseFG_sim_900/'
diffuse.sim_diffuse_fg_map(temp_file, temp_key, sck_params=sck_params, 
                           output_path=output_path, pad=300)
# Out:
# (900, 1200, 1200)
# (900, 1200, 1200)

# %%
pm.show_map(output_path + 'sck_pad300.h5', 'ps_map', 
            indx=(slice(0, None), ), figsize=(6, 4), 
            sigma=6, unit='K')
# Out:
# No mask
