# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import copy
import h5py as h5

from ska_sim import combine_fits as cf

# %%
data_path = '/home/wangyuxin/ska_sim/ws_output/imap00_HI_PS_FG_uw_multiscale/'
data_name = 'Freq115.75MHz-image.fits'

cf.show_map(data_path, data_name, figsize=(8, 8), sigma=0.1)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60310.312674 from DATE-OBS'. [astropy.wcs.wcs]
# (-22885.997677509302,
#  31509.698849384302,
#  <matplotlib.collections.QuadMesh at 0x7f85559b2070>)

# %%
data_path = '/home/wangyuxin/ska_sim/ws_output/imap00_HI_PS_FG_uw_multiscale/'
data_name = 'Freq115.75MHz-dirty.fits'

cf.show_map(data_path, data_name, figsize=(8, 8), sigma=0.1)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60310.312674 from DATE-OBS'. [astropy.wcs.wcs]
# (-28391.963167523176,
#  28495.54478678587,
#  <matplotlib.collections.QuadMesh at 0x7f8554a4f3a0>)
